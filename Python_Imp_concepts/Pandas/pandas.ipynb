# %%
#Q. How do you create a DataFrame from a dictionary?
import pandas as pd
# dict of list
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'City': ['NYC', 'LA', 'Chicago']
}

df = pd.DataFrame(data)

print(df)
# Out:
#       Name  Age     City
# 0    Alice   25      NYC
# 1      Bob   30       LA
# 2  Charlie   35  Chicago

# %%
#dict of dict
data = {
    'row1': {'Name': 'Alice', 'Age': 25},
    'row2': {'Name': 'Bob', 'Age': 30}
}

df = pd.DataFrame.from_dict(data, orient='index')

print(df)
# Out:
#        Name  Age
# row1  Alice   25
# row2    Bob   30

# %%
import json

json_str = '''
[
    {"Name": "Alice", "Age": 25},
    {"Name": "Bob", "Age": 30}
]
'''

# Convert JSON string to DataFrame
df = pd.read_json(json_str)
print(df)
# Out:
# C:\Users\Shashank\AppData\Local\Temp\ipykernel_10032\3125304449.py:11: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(json_str)
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
data = [
    {"Name": "Alice", "Age": 25},
    {"Name": "Bob", "Age": 30}
]

df = pd.DataFrame(data)
print(df)
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30
